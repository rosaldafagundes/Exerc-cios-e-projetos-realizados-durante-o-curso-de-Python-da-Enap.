# %% [markdown]
# <a href="https://colab.research.google.com/github/rosaldafagundes/Exerc-cios-e-projetos-realizados-durante-o-curso-de-Python-da-Enap./blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero = int(input("Digite um dígito de 0 a 9: "))

if numero == 0:
    print("Você inseriu o valor: 0")
elif numero == 1:
    print("Você inseriu o valor: 1")
elif numero == 2:
    print("Você inseriu o valor: 2")
elif numero == 3:
    print("Você inseriu o valor: 3")
elif numero == 4:
    print("Você inseriu o valor: 4")
elif numero == 5:
    print("Você inseriu o valor: 5")
elif numero == 6:
    print("Você inseriu o valor: 6")
elif numero == 7:
    print("Você inseriu o valor: 7")
elif numero == 8:
    print("Você inseriu o valor: 8")
elif numero == 9:
    print("Você inseriu o valor: 9")
else:

    print("invalid inputs")
